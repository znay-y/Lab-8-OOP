// %% [markdown]
// # Lab 7
//
// Deadline: **Week 9** in your respective lab session

// %% [markdown]
// ### Name:
// ### Student ID:

// %% [markdown]
// ***
//
// ## Question 1 [0.75 marks]

// %% [markdown]
// Write a method called `shiftByN` that accepts an ArrayList `a` containing integers and an integer `n`. This method shifts every element in the ArrayList `a` by the value of `n` and updates the ArrayList a accordingly. For example, if `a` is initially `[1, 2, 3, 4, 5]` and `n` is `2`, invoking `shiftByN` will result in `a` being updated to `[4, 5, 1, 2, 3]`.

// %% [markdown]
// **Write your answer below:**

// %%
public static void shiftByN(ArrayList<Integer> a, int amount) {
        for(int i =0; i<amount;i++){
            pushIndex(a);
        }
    }

public static void pushIndex(ArrayList<Integer> xs){
        int toPush= xs.get(0);
        int temp;
        System.out.println("toPush is: "+toPush);

        for(int i =0;i<xs.size()-1;i++){
            temp = xs.get(i+1);
            System.out.println("Adding "+toPush+" where "+xs.get(i+1)+" is rn");
            xs.set(i+1, toPush);
            toPush = temp;
            System.out.println("New toPush value "+toPush);
            System.out.println("\nNew Aray "+xs.toString()+"\n");

        }
        xs.set(0, toPush);
    }

// %% [markdown]
// **Run your program:**

// %%
ArrayList<Integer> a = new ArrayList<>();
a.add(1);
a.add(2);
a.add(3);
a.add(4);
a.add(5);

shiftByN(a, 2);

System.out.println(a.toString());
// Out:
// [4, 5, 1, 2, 3]

// %% [markdown]
// ***
//
// ## Question 2 [0.75 marks]

// %% [markdown]
// Write a method named `getOverlap` that takes two ArrayLists of integers as input and returns an ArrayList containing integers that appear in both ArrayLists. For example, given input ArrayLists `[1, 2, 3]` and `[3, 2]`, the output will be `[2, 3]`. The order of elements in the output list does not matter.

// %% [markdown]
// **Write your answer below:**

// %%
public static ArrayList<Integer> getOverlap(ArrayList<Integer> left, ArrayList<Integer> right) {
        ArrayList<Integer> toReturn = new ArrayList<>();

        for (int leftInd = 0; leftInd < left.size(); leftInd++) {
            for (int rightInd = 0; rightInd < right.size(); rightInd++) {
                int leftValue = left.get(leftInd);
                int rightValue = right.get(rightInd);

                System.out.println("Checking " + leftValue + " with " + rightValue);

                if (leftValue == rightValue) {
                    toReturn.add(leftValue);
                }
            }
        }

        return toReturn;
    }

// %% [markdown]
// **Run your program:**

// %%
ArrayList<Integer> a = new ArrayList<>();
a.add(1);
a.add(2);
a.add(3);

ArrayList<Integer> b = new ArrayList<>();
b.add(3);
b.add(2);

System.out.println(getOverlap(a, b).toString());
// Out:
// [2, 3]

// %% [markdown]
// ***
// ## Question 3 [0.75 marks]

// %% [markdown]
// Write a method `toReversedArrayList` that takes a linked list of strings as input, converts it to an ArrayList in reverse order, and then returns it. For example, given input `["Alice, "Bob", "Charlie"]` the output will be `["Charlie", "Bob", "Alice"]`.

// %% [markdown]
// **Write your answer below:**

// %%
public static LinkedList<String> toReversedArrayList(LinkedList<String> xs) {
        LinkedList<String> toReturn = new LinkedList<>();

        for(int left =xs.size()-1 ; left>=0;left--){
           toReturn.add(xs.get(left));
        }
        return toReturn;
    }

// %% [markdown]
// **Run your program:**

// %%
LinkedList<String> a = new LinkedList<>();
a.add("Alice");
a.add("Bob");
a.add("Charlie");

System.out.println(toReversedArrayList(a).toString());
// Out:
// [Charlie, Bob, Alice]

// %% [markdown]
// ***

// %% [markdown]
// ## Question 4 [0.75 marks]

// %% [markdown]
// Write a method named `getCounts` that takes a linked list of generic type as input and returns a HashMap containing counts of each unique value. For example, given input `["Java", "Python", "Java", "C++"]`, the output will be `{Java=2, C++=1, Python=1}`.

// %% [markdown]
// **Write your answer below:**

// %%
  public static HashMap<String, Integer> getCounts(LinkedList<String> xs) {

        HashMap<String, Integer> counts = new HashMap<>();

        for (int i = 0; i < xs.size(); i++) {
            String counting = xs.get(i);
            int count = 0;
            System.out.println("Looking for " + counting);

            for (int j = 0; j < xs.size(); j++) {
                if (counting.equals(xs.get(j))) {
                    System.out.println(counting + " found in xs array");
                    count++;
                }
            }
            counts.put(counting, count);
        }
        return counts;
    }

// %% [markdown]
// **Run your program:**

// %%
LinkedList<String> a = new LinkedList<>();
a.add("Java");
a.add("Python");
a.add("Java");
a.add("C++");

System.out.println(getCounts(a).toString());
// Out:
// {Java=2, C++=1, Python=1}

// %% [markdown]
// ***

// %% [markdown]
// ## Question 5 [2 marks]

// %% [markdown]
// A bracket refers to any of the following characters: `(`, `)`, `{`, `}`, `[`, or `]`.
//
// A sequence of brackets is **balanced** if every opening bracket is matched by a closing bracket of the same type in the correct order.
//
// Write a method `static boolean matchingBrackets(String s)` hat returns `true` if the brackets in the string are balanced and `false` otherwise.
//
// Requirements:
//
// 1. Your solution **must use a** `Stack<Character>`.
//
// 2. The input string **may contain other characters** which should be ignored.

// %%
import java.util.Stack;

public class BracketMatcher {

    public static boolean matchingBrackets(String s) {

        // Your implementation


    }

}

// %% [markdown]
// Example:

// %%
System.out.println(matchingBrackets("{[()]}"));           // true
System.out.println(matchingBrackets("((({{{[[]]}}})))")); // true
System.out.println(matchingBrackets("(a + b]"));          // false
System.out.println(matchingBrackets("{[(])}"));           // false
